# %%
import pandas as pd

# %%
df=pd.read_csv('ZILLOW-C25709_ZRISFRR.csv')

# %%
df
# Out:
#           Date   Value
# 0   2018-06-30  1305.0
# 1   2018-05-31  1302.0
# 2   2018-04-30  1295.0
# 3   2018-03-31  1288.0
# 4   2018-02-28  1286.0
# 5   2018-01-31  1294.0
# 6   2017-12-31  1308.0
# 7   2017-11-30  1319.0
# 8   2017-10-31  1317.0
# 9   2017-09-30  1302.0
# 10  2017-08-31  1286.0
# 11  2017-07-31  1278.0
# 12  2017-06-30  1272.0
# 13  2017-05-31  1263.0
# 14  2017-04-30  1255.0
# 15  2017-03-31  1251.0
# 16  2017-02-28  1255.0
# 17  2017-01-31  1266.0
# 18  2016-12-31  1281.0
# 19  2016-11-30  1299.0
# 20  2016-10-31  1317.0
# 21  2016-09-30  1334.0
# 22  2016-08-31  1346.0
# 23  2016-07-31  1342.0
# 24  2016-06-30  1331.0
# 25  2016-05-31  1319.0
# 26  2016-04-30  1314.0
# 27  2016-03-31  1313.0
# 28  2016-02-29  1298.0
# 29  2016-01-31  1293.0
# ..         ...     ...
# 62  2013-04-30  1324.0
# 63  2013-03-31  1317.0
# 64  2013-02-28  1338.0
# 65  2013-01-31  1319.0
# 66  2012-12-31  1281.0
# 67  2012-11-30  1271.0
# 68  2012-10-31  1306.0
# 69  2012-09-30  1323.0
# ...

# %%
df.head()
# Out:
#          Date   Value
# 0  2018-06-30  1305.0
# 1  2018-05-31  1302.0
# 2  2018-04-30  1295.0
# 3  2018-03-31  1288.0
# 4  2018-02-28  1286.0

# %%
df.set_index('Date',inplace =True)

# %%
df.to_csv('newcsv2.csv')

# %%
df=pd.read_csv('newcsv2.csv')

# %%
df.head(2)
# Out:
#          Date   Value
# 0  2018-06-30  1305.0
# 1  2018-05-31  1302.0

# %%
df=pd.read_csv('newcsv2.csv',index_col=1)

# %%
df.head()
# Out:
#             Hutiya
# Date
# 1305.0  2018-06-30
# 1302.0  2018-05-31
# 1295.0  2018-04-30
# 1288.0  2018-03-31
# 1286.0  2018-02-28

# %%
#To rename the columns

# %%
df.columns=['HousePriceIndex']

# %%
df.head()
# Out:
#             Hutiya
# Date
# 1305.0  2018-06-30
# 1302.0  2018-05-31
# 1295.0  2018-04-30
# 1288.0  2018-03-31
# 1286.0  2018-02-28

# %%
df.to_csv('newcsv3.csv')

# %%
df.to_csv('newcsv4.csv',header=False)

# %%
df=pd.read_csv('newcsv4.csv',names=['Date','Hutiya'],index_col=0)

# %%
df.head()
# Out:
#             Hutiya
# Date
# 1305.0  2018-06-30
# 1302.0  2018-05-31
# 1295.0  2018-04-30
# 1288.0  2018-03-31
# 1286.0  2018-02-28

# %%
#To convert it to html

df.to_html('newHtml.html')

# %%
df=pd.read_csv('newcsv4.csv',names=['Date','Hutiya'],index_col=0)

# %%
df.rename(columns = {'Hutiya' : 'Chutiya'} ,inplace =True)

# %%
df.head(2)
# Out:
#            Chutiya
# Date
# 1305.0  2018-06-30
# 1302.0  2018-05-31
