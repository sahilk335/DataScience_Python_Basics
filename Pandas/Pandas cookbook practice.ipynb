# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
movie = pd.read_csv('data/movie.csv')

# %%
movie.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
director = movie['director_name']
critics = movie['num_critic_for_reviews']

# %%
director.value_counts().head()
# Out:
# Steven Spielberg    26
# Woody Allen         22
# Clint Eastwood      20
# Martin Scorsese     20
# Ridley Scott        16
# Name: director_name, dtype: int64

# %%
# To count number of null in columns

# %%
director.isnull().sum()
# Out:
# 102

# %%
critics.isnull()\
.sum()
# Out:
# 49

# %%
critics.isnull().sum()
# Out:
# 49

# %%
movie = pd.read_csv('data/movie.csv')

# %%
movie.isnull().head()
# Out:
#    color  director_name  num_critic_for_reviews  duration  \
# 0  False          False                   False     False
# 1  False          False                   False     False
# 2  False          False                   False     False
# 3  False          False                   False     False
# 4   True          False                    True      True
#
#    director_facebook_likes  actor_3_facebook_likes  actor_2_name  \
# 0                    False                   False         False
# 1                    False                   False         False
# 2                    False                   False         False
# 3                    False                   False         False
# 4                    False                    True         False
#
#    actor_1_facebook_likes  gross  genres          ...           \
# 0                   False  False   False          ...
# 1                   False  False   False          ...
# ...

# %%
movie.isnull().sum().sum()
# Out:
# 2654

# %%
movie.any()
# Out:
# color                        True
# director_name                True
# num_critic_for_reviews       True
# duration                     True
# director_facebook_likes      True
# actor_3_facebook_likes       True
# actor_2_name                 True
# actor_1_facebook_likes       True
# gross                        True
# genres                       True
# actor_1_name                 True
# movie_title                  True
# num_voted_users              True
# cast_total_facebook_likes    True
# actor_3_name                 True
# facenumber_in_poster         True
# plot_keywords                True
# movie_imdb_link              True
# num_user_for_reviews         True
# language                     True
# country                      True
# content_rating               True
# budget                       True
# title_year                   True
# actor_2_facebook_likes       True
# imdb_score                   True
# aspect_ratio                 True
# ...

# %%
import pandas as pd

# %%
movie = pd.read_csv('data/movie.csv')

# %%
movie.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
movie.dtypes
# Out:
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews         float64
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# ...

# %%
movie.select_dtypes(['object']).head()
# Out:
#    color      director_name      actor_2_name  \
# 0  Color      James Cameron  Joel David Moore
# 1  Color     Gore Verbinski     Orlando Bloom
# 2  Color         Sam Mendes      Rory Kinnear
# 3  Color  Christopher Nolan    Christian Bale
# 4    NaN        Doug Walker        Rob Walker
#
#                             genres     actor_1_name  \
# 0  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1         Action|Adventure|Fantasy      Johnny Depp
# 2        Action|Adventure|Thriller  Christoph Waltz
# 3                  Action|Thriller        Tom Hardy
# 4                      Documentary      Doug Walker
#
#                                   movie_title          actor_3_name  \
# 0                                      Avatar             Wes Studi
# 1    Pirates of the Caribbean: At World's End        Jack Davenport
# 2                                     Spectre      Stephanie Sigman
# 3                       The Dark Knight Rises  Joseph Gordon-Levitt
# ...

# %%
movie.select_dtypes(['object']).fillna('').min()
# Out:
# color
# director_name
# actor_2_name
# genres                                                        Action
# actor_1_name
# movie_title                                                  #Horror
# actor_3_name
# plot_keywords
# movie_imdb_link    http://www.imdb.com/title/tt0006864/?ref_=fn_t...
# language
# country
# content_rating
# dtype: object

# %%
college = pd.read_csv('data/college.csv',index_col='INSTNM')

# %%
college.head(2)
# Out:
#                                            CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Alabama A & M University                 Normal     AL   1.0      0.0
# University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
#
#                                      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# Alabama A & M University                   0.0         0     424.0     420.0
# University of Alabama at Birmingham        0.0         0     570.0     565.0
#
#                                      DISTANCEONLY     UGDS  \
# INSTNM
# Alabama A & M University                      0.0   4206.0
# University of Alabama at Birmingham           0.0  11383.0
#
#                                             ...          UGDS_2MOR  UGDS_NRA  \
# INSTNM                                      ...
# Alabama A & M University                    ...             0.0000    0.0059
# University of Alabama at Birmingham         ...             0.0368    0.0179
#
# ...

# %%
college_ugds = college.filter(like='UGDS_')

# %%
college_ugds.head()
# Out:
#                                      UGDS_WHITE  UGDS_BLACK  UGDS_HISP  \
# INSTNM
# Alabama A & M University                 0.0333      0.9353     0.0055
# University of Alabama at Birmingham      0.5922      0.2600     0.0283
# Amridge University                       0.2990      0.4192     0.0069
# University of Alabama in Huntsville      0.6988      0.1255     0.0382
# Alabama State University                 0.0158      0.9208     0.0121
#
#                                      UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# INSTNM
# Alabama A & M University                 0.0019     0.0024     0.0019
# University of Alabama at Birmingham      0.0518     0.0022     0.0007
# Amridge University                       0.0034     0.0000     0.0000
# University of Alabama in Huntsville      0.0376     0.0143     0.0002
# Alabama State University                 0.0019     0.0010     0.0006
#
#                                      UGDS_2MOR  UGDS_NRA  UGDS_UNKN
# INSTNM
# ...

# %%
college_ugds + 1
# Out:
#                                                     UGDS_WHITE  UGDS_BLACK  \
# INSTNM
# Alabama A & M University                                1.0333      1.9353
# University of Alabama at Birmingham                     1.5922      1.2600
# Amridge University                                      1.2990      1.4192
# University of Alabama in Huntsville                     1.6988      1.1255
# Alabama State University                                1.0158      1.9208
# The University of Alabama                               1.7825      1.1119
# Central Alabama Community College                       1.7255      1.2613
# Athens State University                                 1.7823      1.1200
# Auburn University at Montgomery                         1.5328      1.3376
# Auburn University                                       1.8507      1.0704
# Birmingham Southern College                             1.7983      1.1102
# ...

# %%
college_ugds.count(axis='index')
# Out:
# UGDS_WHITE    6874
# UGDS_BLACK    6874
# UGDS_HISP     6874
# UGDS_ASIAN    6874
# UGDS_AIAN     6874
# UGDS_NHPI     6874
# UGDS_2MOR     6874
# UGDS_NRA      6874
# UGDS_UNKN     6874
# dtype: int64

# %%
import pandas as pd

# %%
college = pd.read_csv('data/college.csv',index_col="INSTNM")

# %%
college.head()
# Out:
#                                            CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Alabama A & M University                 Normal     AL   1.0      0.0
# University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# Amridge University                   Montgomery     AL   0.0      0.0
# University of Alabama in Huntsville  Huntsville     AL   0.0      0.0
# Alabama State University             Montgomery     AL   1.0      0.0
#
#                                      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# Alabama A & M University                   0.0         0     424.0     420.0
# University of Alabama at Birmingham        0.0         0     570.0     565.0
# Amridge University                         0.0         1       NaN       NaN
# University of Alabama in Huntsville        0.0         0     595.0     590.0
# Alabama State University                   0.0         0     425.0     430.0
#
#                                      DISTANCEONLY     UGDS  \
# ...

# %%
college_ugds = college.filter(like="UGDS_")

# %%
college_ugds.head()
# Out:
#                                      UGDS_WHITE  UGDS_BLACK  UGDS_HISP  \
# INSTNM
# Alabama A & M University                 0.0333      0.9353     0.0055
# University of Alabama at Birmingham      0.5922      0.2600     0.0283
# Amridge University                       0.2990      0.4192     0.0069
# University of Alabama in Huntsville      0.6988      0.1255     0.0382
# Alabama State University                 0.0158      0.9208     0.0121
#
#                                      UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# INSTNM
# Alabama A & M University                 0.0019     0.0024     0.0019
# University of Alabama at Birmingham      0.0518     0.0022     0.0007
# Amridge University                       0.0034     0.0000     0.0000
# University of Alabama in Huntsville      0.0376     0.0143     0.0002
# Alabama State University                 0.0019     0.0010     0.0006
#
#                                      UGDS_2MOR  UGDS_NRA  UGDS_UNKN
# INSTNM
# ...

# %%
college_ugds.isnull() \
.sum(axis=1) \
.sort_values(ascending=False) \
.head()
# Out:
# INSTNM
# Excel Learning Center-San Antonio South         9
# Philadelphia College of Osteopathic Medicine    9
# Assemblies of God Theological Seminary          9
# Episcopal Divinity School                       9
# Phillips Graduate Institute                     9
# dtype: int64

# %%
college_ugds = college_ugds.dropna(how="all")

# %%
college_ugds.isnull().sum().sum()
# Out:
# 0

# %%
diversity_metric =college_ugds.ge(.15).sum(axis="columns")

# %%
diversity_metric.sort_values(ascending=False)
# Out:
# INSTNM
# Regency Beauty Institute-Austin                                           5
# Central Texas Beauty College-Temple                                       5
# Sullivan and Cogliano Training Center                                     4
# Ambria College of Nursing                                                 4
# Berkeley College-New York                                                 4
# Charles A Jones Career and Education Center                               4
# J Renee College                                                           4
# Bramson ORT College                                                       4
# Pacific Rim Christian University                                          4
# Bristol University                                                        4
# Los Angeles Film School                                                   4
# Merritt College                                                           4
# ...

# %%
top=college_ugds.loc[['Regency Beauty Institute-Austin','Westwood College-River Oaks']]

# %%
diversity_metric.loc[]
# Out:
#   File "<ipython-input-1-c7fdf80e66cd>", line 1
#     diversity_metric.loc[]
#                          ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

# %%
college = pd.read_csv('data/college.csv',index_col="INSTNM")

# %%
college.head()
# Out:
#                                            CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Alabama A & M University                 Normal     AL   1.0      0.0
# University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# Amridge University                   Montgomery     AL   0.0      0.0
# University of Alabama in Huntsville  Huntsville     AL   0.0      0.0
# Alabama State University             Montgomery     AL   1.0      0.0
#
#                                      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# Alabama A & M University                   0.0         0     424.0     420.0
# University of Alabama at Birmingham        0.0         0     570.0     565.0
# Amridge University                         0.0         1       NaN       NaN
# University of Alabama in Huntsville        0.0         0     595.0     590.0
# Alabama State University                   0.0         0     425.0     430.0
#
#                                      DISTANCEONLY     UGDS  \
# ...

# %%
city=college.iloc[3]

# %%
city
# Out:
# CITY                  Huntsville
# STABBR                        AL
# HBCU                           0
# MENONLY                        0
# WOMENONLY                      0
# RELAFFIL                       0
# SATVRMID                     595
# SATMTMID                     590
# DISTANCEONLY                   0
# UGDS                        5451
# UGDS_WHITE                0.6988
# UGDS_BLACK                0.1255
# UGDS_HISP                 0.0382
# UGDS_ASIAN                0.0376
# UGDS_AIAN                 0.0143
# UGDS_NHPI                 0.0002
# UGDS_2MOR                 0.0172
# UGDS_NRA                  0.0332
# UGDS_UNKN                  0.035
# PPTUG_EF                  0.2146
# CURROPER                       1
# PCTPELL                   0.3072
# PCTFLOAN                  0.4596
# UG25ABV                    0.264
# MD_EARN_WNE_P10            45500
# GRAD_DEBT_MDN_SUPP         24097
# Name: University of Alabama in Huntsville, dtype: object

# %%
import pandas as pd

# %%
college = pd.read_csv("data/college.csv",index_col="INSTNM")

# %%
college.head()
# Out:
#                                            CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Alabama A & M University                 Normal     AL   1.0      0.0
# University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# Amridge University                   Montgomery     AL   0.0      0.0
# University of Alabama in Huntsville  Huntsville     AL   0.0      0.0
# Alabama State University             Montgomery     AL   1.0      0.0
#
#                                      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# Alabama A & M University                   0.0         0     424.0     420.0
# University of Alabama at Birmingham        0.0         0     570.0     565.0
# Amridge University                         0.0         1       NaN       NaN
# University of Alabama in Huntsville        0.0         0     595.0     590.0
# Alabama State University                   0.0         0     425.0     430.0
#
#                                      DISTANCEONLY     UGDS  \
# ...

# %%
college.loc[['University of Alaska Anchorage']]
# Out:
#                                      CITY STABBR  HBCU  MENONLY  WOMENONLY  \
# INSTNM
# University of Alaska Anchorage  Anchorage     AK   0.0      0.0        0.0
#
#                                 RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  \
# INSTNM
# University of Alaska Anchorage         0       NaN       NaN           0.0
#
#                                    UGDS         ...          UGDS_2MOR  \
# INSTNM                                          ...
# University of Alaska Anchorage  12865.0         ...              0.098
#
#                                 UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  \
# INSTNM
# University of Alaska Anchorage    0.0181     0.0457    0.4539         1
#
#                                 PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# INSTNM
# University of Alaska Anchorage   0.2385    0.2647   0.4386            42500
#
#                                 GRAD_DEBT_MDN_SUPP
# INSTNM
# University of Alaska Anchorage             19449.5
#
# ...

# %%
college.head()
# Out:
#                                            CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Alabama A & M University                 Normal     AL   1.0      0.0
# University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# Amridge University                   Montgomery     AL   0.0      0.0
# University of Alabama in Huntsville  Huntsville     AL   0.0      0.0
# Alabama State University             Montgomery     AL   1.0      0.0
#
#                                      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# Alabama A & M University                   0.0         0     424.0     420.0
# University of Alabama at Birmingham        0.0         0     570.0     565.0
# Amridge University                         0.0         1       NaN       NaN
# University of Alabama in Huntsville        0.0         0     595.0     590.0
# Alabama State University                   0.0         0     425.0     430.0
#
#                                      DISTANCEONLY     UGDS  \
# ...

# %%
college.iloc[:3,:2]
# Out:
#                                            CITY STABBR
# INSTNM
# Alabama A & M University                 Normal     AL
# University of Alabama at Birmingham  Birmingham     AL
# Amridge University                   Montgomery     AL

# %%
college.iloc[:,[4,6]].head()
# Out:
#                                      WOMENONLY  SATVRMID
# INSTNM
# Alabama A & M University                   0.0     424.0
# University of Alabama at Birmingham        0.0     570.0
# Amridge University                         0.0       NaN
# University of Alabama in Huntsville        0.0     595.0
# Alabama State University                   0.0     425.0

# %%
college.iloc[[1,2],[1,2]]
# Out:
#                                     STABBR  HBCU
# INSTNM
# University of Alabama at Birmingham     AL   0.0
# Amridge University                      AL   0.0

# %%
college.iloc[1,-1]
# Out:
# '21941.5'

# %%
college.loc["University of Alabama at Birmingham":"Amridge University","CITY"]
# Out:
# INSTNM
# University of Alabama at Birmingham    Birmingham
# Amridge University                     Montgomery
# Name: CITY, dtype: object

# %%
college = pd.read_csv("data/college.csv",index_col="INSTNM")

# %%
college.head()
# Out:
#                                            CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Alabama A & M University                 Normal     AL   1.0      0.0
# University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# Amridge University                   Montgomery     AL   0.0      0.0
# University of Alabama in Huntsville  Huntsville     AL   0.0      0.0
# Alabama State University             Montgomery     AL   1.0      0.0
#
#                                      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# INSTNM
# Alabama A & M University                   0.0         0     424.0     420.0
# University of Alabama at Birmingham        0.0         0     570.0     565.0
# Amridge University                         0.0         1       NaN       NaN
# University of Alabama in Huntsville        0.0         0     595.0     590.0
# Alabama State University                   0.0         0     425.0     430.0
#
#                                      DISTANCEONLY     UGDS  \
# ...

# %%
col_start = college.columns.get_loc("UGDS_WHITE")

# %%
col_start
# Out:
# 10
