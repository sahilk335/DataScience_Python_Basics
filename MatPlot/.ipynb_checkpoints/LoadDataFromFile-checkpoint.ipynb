# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x,y = np.loadtxt('sample.csv',delimiter=',',unpack=True)

# %%
plt.plot(x,y,label="Loaded CSV file")
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.title("Plots line")
plt.legend()
plt.show()
